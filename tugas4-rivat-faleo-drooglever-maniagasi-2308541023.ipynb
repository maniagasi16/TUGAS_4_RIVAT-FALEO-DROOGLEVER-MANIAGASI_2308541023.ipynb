# %%
nama = ['rivat','yuda','wira','maruli']
print (nama)
# Out:
# ['rivat', 'yuda', 'wira', 'maruli']

# %%
print (nama[0])
# Out:
# rivat

# %%
print (nama[2])
# Out:
# wira

# %%
nama = ['rivat', 'yuda', 'wira', 'maruli']
nama[1] = 'anggi'
print (nama)
# Out:
# ['rivat', 'anggi', 'wira', 'maruli']

# %%
nama = ['rivat', 'yuda', 'wira', 'maruli']
nama[3] = 'anggi'
print (nama)
# Out:
# ['rivat', 'yuda', 'wira', 'anggi']

# %%
jurusan = ['matematika','fisika','biologi','farmasi','informatika']
jurusan.append('kimia')
print(jurusan)
# Out:
# ['matematika', 'fisika', 'biologi', 'farmasi', 'informatika', 'kimia']

# %%
jurusan.insert (0,'matematika')
print (jurusan)
# Out:
# ['matematika', 'matematika', 'fisika', 'biologi', 'farmasi', 'informatika', 'kimia']

# %%
jurusan.remove ('fisika')
print (jurusan)
# Out:
# ['matematika', 'matematika', 'biologi', 'farmasi', 'informatika', 'kimia']

# %%
hewan = ['anjing','kucing','babi','ayam','kelinci','cicak','tikus',]
for jenis in hewan:
    print (hewan)
# Out:
# ['anjing', 'kucing', 'babi', 'ayam', 'kelinci', 'cicak', 'tikus']
# ['anjing', 'kucing', 'babi', 'ayam', 'kelinci', 'cicak', 'tikus']
# ['anjing', 'kucing', 'babi', 'ayam', 'kelinci', 'cicak', 'tikus']
# ['anjing', 'kucing', 'babi', 'ayam', 'kelinci', 'cicak', 'tikus']
# ['anjing', 'kucing', 'babi', 'ayam', 'kelinci', 'cicak', 'tikus']
# ['anjing', 'kucing', 'babi', 'ayam', 'kelinci', 'cicak', 'tikus']
# ['anjing', 'kucing', 'babi', 'ayam', 'kelinci', 'cicak', 'tikus']

# %%
i=1
while i < len (hewan):
    print (hewan[i])
    i+=2
# Out:
# kucing
# ayam
# cicak
